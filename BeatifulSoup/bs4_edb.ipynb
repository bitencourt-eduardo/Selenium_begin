# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://kabum.com.br/'
header = {'User-Agent': 'Mozilla/5.0'}
kabum_response = requests.get(url, headers=header)
kabum_response
# Out:
# <Response [200]>

# %%
kabum_soup = BeautifulSoup(kabum_response.text, 'html.parser')

# %%
kabum_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
ofertas = kabum_soup.find('div',{'class':'carrosselProdutos'})

# %%
ofertas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/Eduardo/Documents/GitHub/WebScraping/BeatifulSoup/bs4_edb.ipynb Célula 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/Eduardo/Documents/GitHub/WebScraping/BeatifulSoup/bs4_edb.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> ofertas
#
# NameError: name 'ofertas' is not defined
